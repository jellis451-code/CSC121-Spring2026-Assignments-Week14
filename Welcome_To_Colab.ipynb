# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-Week14/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS
class Book:
    # __init__(title, author)
    #   set self.title = title
    #   set self.author = author
    #   set self.is_available = True

    # __str__()
    #   if self.is_available is True:
    #       return "Title by Author - Available"
    #   else:
    #       return "Title by Author - Checked Out"

    # checkout()
    #   set self.is_available = False

    # return_book()
    #   set self.is_available = True

    pass   # ✅ THIS FIXES THE ERROR


# PROGRAM LOGIC
# create book1 and book2 objects
# print both books
# checkout one book
# print both books again to show that only one book's status changed
